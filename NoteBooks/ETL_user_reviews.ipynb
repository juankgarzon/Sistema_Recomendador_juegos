# %%
# Importacion de Librerias
import pandas as pd
import ast
import utils
import re
import gzip

# %%
# Se lee el dataset que contiene las reviews que hacen los usuarios y se guarda en un dataframe

# Carga del dataframe con el archivo user_reviews.json.gz
data = []
with gzip.open('dataset/user_reviews.json.gz', 'rt', encoding='utf-8') as file:
    for line in file:
        try:
            # Suponiendo que las líneas contienen datos JSON válidos
            json_data = eval(line.strip())  # Suponiendo una estructura JSON simple, use ast.literal_eval() para mayor seguridad
            data.append(json_data)
        except ValueError as e:
            print(f"Error en la línea: {line}")
            continue

df_reviews = pd.DataFrame(data)
df_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# 0      [{'funny': '', 'posted': 'Posted November 5, 2...
# 1      [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2      [{'funny': '', 'posted': 'Posted February 3.',...
# 3      [{'funny': '', 'posted': 'Posted October 14, 2...
# 4      [{'funny': '3 people found this review funny',...
# ...                                                  ...
# 25794  [{'funny': '', 'posted': 'Posted May 31.', 'la...
# 25795  [{'funny': '', 'posted': 'Posted June 17.', 'l...
# 25796  [{'funny': '1 person found this review funny',...
# 25797  [{'funny': '', 'posted': 'Posted July 21.', 'l...
# 25798  [{'funny': '1 person found this review funny',...
#
# [25799 rows x 3 columns]

# %%
# Observamos la estructura del archivo
df_reviews.info()
df_reviews.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25799 entries, 0 to 25798
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   25799 non-null  object
#  1   user_url  25799 non-null  object
#  2   reviews   25799 non-null  object
# dtypes: object(3)
# memory usage: 604.8+ KB
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...
# 3  [{'funny': '', 'posted': 'Posted October 14, 2...
# 4  [{'funny': '3 people found this review funny',...

# %%
# Mostrar los nombres de las columnas disponibles del DataFrame user_reviews
print(df_reviews.columns)

# Mostrar sus tipos de datos
for column in df_reviews.columns:
    print(f"Etiqueta: {column}, Tipo de dato: {df_reviews[column].dtype}")
# Out:
# Index(['user_id', 'user_url', 'reviews'], dtype='object')
# Etiqueta: user_id, Tipo de dato: object
# Etiqueta: user_url, Tipo de dato: object
# Etiqueta: reviews, Tipo de dato: object

# %%
# Verificar duplicados
tiene_duplicados = df_reviews['user_id'].duplicated().any()
duplicados = df_reviews[df_reviews['user_id'].duplicated()]['user_id']
print(duplicados)
# Out:
# 456             bokkkbokkk
# 1182            ImSeriouss
# 1456     76561198062039159
# 1477     76561198045009232
# 1746          nitr0ticwolf
#                ...
# 17819    76561198076474887
# 17916          yolofaceguy
# 18028    76561198075591109
# 18234    76561198092022514
# 18309       SuchGayMuchWow
# Name: user_id, Length: 314, dtype: object

# %%
# Confirmamos la data
df_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# 0      [{'funny': '', 'posted': 'Posted November 5, 2...
# 1      [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2      [{'funny': '', 'posted': 'Posted February 3.',...
# 3      [{'funny': '', 'posted': 'Posted October 14, 2...
# 4      [{'funny': '3 people found this review funny',...
# ...                                                  ...
# 25794  [{'funny': '', 'posted': 'Posted May 31.', 'la...
# 25795  [{'funny': '', 'posted': 'Posted June 17.', 'l...
# 25796  [{'funny': '1 person found this review funny',...
# 25797  [{'funny': '', 'posted': 'Posted July 21.', 'l...
# 25798  [{'funny': '1 person found this review funny',...
#
# [25799 rows x 3 columns]

# %%
# La columna 'reviews' se presenta anidada, siendo una lista con uno o mas diccionarios como elementos. 
# Se decide separar por diccionario

# Se transforma a columnas cada elemento de las listas
df_reviews_separado = pd.json_normalize(df_reviews['reviews'])
df_reviews_separado.head()
# Out:
#                                                    0  \
# 0  {'funny': '', 'posted': 'Posted November 5, 20...
# 1  {'funny': '', 'posted': 'Posted June 24, 2014....
# 2  {'funny': '', 'posted': 'Posted February 3.', ...
# 3  {'funny': '', 'posted': 'Posted October 14, 20...
# 4  {'funny': '3 people found this review funny', ...
#
#                                                    1  \
# 0  {'funny': '', 'posted': 'Posted July 15, 2011....
# 1  {'funny': '', 'posted': 'Posted September 8, 2...
# 2  {'funny': '', 'posted': 'Posted December 4, 20...
# 3  {'funny': '', 'posted': 'Posted July 28, 2012....
# 4  {'funny': '1 person found this review funny', ...
#
#                                                    2  \
# 0  {'funny': '', 'posted': 'Posted April 21, 2011...
# 1  {'funny': '', 'posted': 'Posted November 29, 2...
# 2  {'funny': '', 'posted': 'Posted November 3, 20...
# 3  {'funny': '', 'posted': 'Posted June 2, 2012.'...
# 4  {'funny': '2 people found this review funny', ...
#
#                                                    3  \
# 0                                               None
# 1                                               None
# 2  {'funny': '', 'posted': 'Posted October 15, 20...
# 3  {'funny': '', 'posted': 'Posted June 29, 2014....
# 4  {'funny': '', 'posted': 'Posted July 11, 2013....
#
#                                                    4  \
# 0                                               None
# 1                                               None
# 2  {'funny': '', 'posted': 'Posted October 15, 20...
# 3  {'funny': '', 'posted': 'Posted November 22, 2...
# 4                                               None
#
#                                                    5     6     7     8     9
# 0                                               None  None  None  None  None
# 1                                               None  None  None  None  None
# 2  {'funny': '', 'posted': 'Posted October 15, 20...  None  None  None  None
# 3  {'funny': '', 'posted': 'Posted February 23, 2...  None  None  None  None
# 4                                               None  None  None  None  None

# %%
# Se oberva que user_id' y 'user_url' desaparecen, lo se concatena con el dataframe anterior

# Se agrega el 'user_id' y 'user_url' a las columnas separadas 
df_reviews_separado = pd.concat([df_reviews[['user_id', 'user_url']], df_reviews_separado], axis=1)
df_reviews_separado.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                                    0  \
# 0  {'funny': '', 'posted': 'Posted November 5, 20...
# 1  {'funny': '', 'posted': 'Posted June 24, 2014....
# 2  {'funny': '', 'posted': 'Posted February 3.', ...
# 3  {'funny': '', 'posted': 'Posted October 14, 20...
# 4  {'funny': '3 people found this review funny', ...
#
#                                                    1  \
# 0  {'funny': '', 'posted': 'Posted July 15, 2011....
# 1  {'funny': '', 'posted': 'Posted September 8, 2...
# 2  {'funny': '', 'posted': 'Posted December 4, 20...
# 3  {'funny': '', 'posted': 'Posted July 28, 2012....
# 4  {'funny': '1 person found this review funny', ...
#
#                                                    2  \
# 0  {'funny': '', 'posted': 'Posted April 21, 2011...
# 1  {'funny': '', 'posted': 'Posted November 29, 2...
# 2  {'funny': '', 'posted': 'Posted November 3, 20...
# 3  {'funny': '', 'posted': 'Posted June 2, 2012.'...
# 4  {'funny': '2 people found this review funny', ...
#
#                                                    3  \
# 0                                               None
# 1                                               None
# 2  {'funny': '', 'posted': 'Posted October 15, 20...
# 3  {'funny': '', 'posted': 'Posted June 29, 2014....
# 4  {'funny': '', 'posted': 'Posted July 11, 2013....
#
#                                                    4  \
# 0                                               None
# 1                                               None
# 2  {'funny': '', 'posted': 'Posted October 15, 20...
# 3  {'funny': '', 'posted': 'Posted November 22, 2...
# 4                                               None
#
#                                                    5     6     7     8     9
# 0                                               None  None  None  None  None
# 1                                               None  None  None  None  None
# 2  {'funny': '', 'posted': 'Posted October 15, 20...  None  None  None  None
# 3  {'funny': '', 'posted': 'Posted February 23, 2...  None  None  None  None
# 4                                               None  None  None  None  None

# %% [markdown]
# Ahora que se tienen los diccionarios por columnas, con el usuario que genera dicha información, se genera un registro por cada diccionario, manteniendo en cada caso el usuario que lo genera.

# %%
# Se adiciona un registro por cada diccionario usando pd.melt
df_reviews_separado = pd.melt(df_reviews_separado, id_vars=['user_id', 'user_url'], 
                       value_vars=list(range(9)),
                       value_name='reviews')
df_reviews_separado.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#   variable                                            reviews
# 0        0  {'funny': '', 'posted': 'Posted November 5, 20...
# 1        0  {'funny': '', 'posted': 'Posted June 24, 2014....
# 2        0  {'funny': '', 'posted': 'Posted February 3.', ...
# 3        0  {'funny': '', 'posted': 'Posted October 14, 20...
# 4        0  {'funny': '3 people found this review funny', ...

# %%
# Obsservamos si tenemos nulos
df_reviews_separado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232191 entries, 0 to 232190
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   232191 non-null  object
#  1   user_url  232191 non-null  object
#  2   variable  232191 non-null  object
#  3   reviews   59036 non-null   object
# dtypes: object(4)
# memory usage: 7.1+ MB

# %%
# Se eliminan las filas con valor None de la columna reviews
df_reviews_separado = df_reviews_separado.dropna()

# Obsservamos si tenemos nulos
df_reviews_separado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59036 entries, 0 to 232129
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   59036 non-null  object
#  1   user_url  59036 non-null  object
#  2   variable  59036 non-null  object
#  3   reviews   59036 non-null  object
# dtypes: object(4)
# memory usage: 2.3+ MB

# %%
# Se transforma  cada diccionario en columna.
# Se separan por columnas cada una de las claves de 'reviews'
df_reviews = df_reviews_separado['reviews'].apply(pd.Series, dtype='object')
df_reviews = df_reviews.add_prefix('reviews_')
df_reviews.head()
# Out:
#                       reviews_funny            reviews_posted  \
# 0                                    Posted November 5, 2011.
# 1                                       Posted June 24, 2014.
# 2                                          Posted February 3.
# 3                                    Posted October 14, 2013.
# 4  3 people found this review funny    Posted April 15, 2014.
#
#   reviews_last_edited reviews_item_id  \
# 0                                1250
# 1                              251610
# 2                              248820
# 3                              250320
# 4                              211420
#
#                                    reviews_helpful  reviews_recommend  \
# 0                                   No ratings yet               True
# 1  15 of 20 people (75%) found this review helpful               True
# 2                                   No ratings yet               True
# 3   2 of 2 people (100%) found this review helpful               True
# 4  35 of 43 people (81%) found this review helpful               True
#
#                                       reviews_review
# 0  Simple yet with great replayability. In my opi...
# 1  I know what you think when you see this title ...
# 2  A suitably punishing roguelike platformer.  Wi...
# 3  This game... is so fun. The fight sequences ha...
# 4                                            Git gud

# %%
# Se concatena nuevamente 'user_id' y 'user_url'
# Se une con el 'user_id' y 'user_url'
df_reviews = pd.concat([df_reviews_separado[['user_id', 'user_url']], df_reviews], axis=1)
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                       reviews_funny            reviews_posted  \
# 0                                    Posted November 5, 2011.
# 1                                       Posted June 24, 2014.
# 2                                          Posted February 3.
# 3                                    Posted October 14, 2013.
# 4  3 people found this review funny    Posted April 15, 2014.
#
#   reviews_last_edited reviews_item_id  \
# 0                                1250
# 1                              251610
# 2                              248820
# 3                              250320
# 4                              211420
#
#                                    reviews_helpful  reviews_recommend  \
# 0                                   No ratings yet               True
# 1  15 of 20 people (75%) found this review helpful               True
# 2                                   No ratings yet               True
# 3   2 of 2 people (100%) found this review helpful               True
# 4  35 of 43 people (81%) found this review helpful               True
#
#                                       reviews_review
# 0  Simple yet with great replayability. In my opi...
# 1  I know what you think when you see this title ...
# 2  A suitably punishing roguelike platformer.  Wi...
# 3  This game... is so fun. The fight sequences ha...
# 4                                            Git gud

# %%
# Se reemplazar espacios vacios con nulos
df_reviews.replace('', None, inplace=True)
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                       reviews_funny            reviews_posted  \
# 0                              None  Posted November 5, 2011.
# 1                              None     Posted June 24, 2014.
# 2                              None        Posted February 3.
# 3                              None  Posted October 14, 2013.
# 4  3 people found this review funny    Posted April 15, 2014.
#
#   reviews_last_edited reviews_item_id  \
# 0                None            1250
# 1                None          251610
# 2                None          248820
# 3                None          250320
# 4                None          211420
#
#                                    reviews_helpful  reviews_recommend  \
# 0                                   No ratings yet               True
# 1  15 of 20 people (75%) found this review helpful               True
# 2                                   No ratings yet               True
# 3   2 of 2 people (100%) found this review helpful               True
# 4  35 of 43 people (81%) found this review helpful               True
#
#                                       reviews_review
# 0  Simple yet with great replayability. In my opi...
# 1  I know what you think when you see this title ...
# 2  A suitably punishing roguelike platformer.  Wi...
# 3  This game... is so fun. The fight sequences ha...
# 4                                            Git gud

# %%
# Se eliminan las columnas reviews_funny y reviews_last_edited que poseen nulos y que no se consideran necesarios
df_reviews = df_reviews.drop(columns=['reviews_funny', 'reviews_last_edited'])
df_reviews.columns
# Out:
# Index(['user_id', 'user_url', 'reviews_posted', 'reviews_item_id',
#        'reviews_helpful', 'reviews_recommend', 'reviews_review'],
#       dtype='object')

# %%
# Confirmanos la data
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#              reviews_posted reviews_item_id  \
# 0  Posted November 5, 2011.            1250
# 1     Posted June 24, 2014.          251610
# 2        Posted February 3.          248820
# 3  Posted October 14, 2013.          250320
# 4    Posted April 15, 2014.          211420
#
#                                    reviews_helpful  reviews_recommend  \
# 0                                   No ratings yet               True
# 1  15 of 20 people (75%) found this review helpful               True
# 2                                   No ratings yet               True
# 3   2 of 2 people (100%) found this review helpful               True
# 4  35 of 43 people (81%) found this review helpful               True
#
#                                       reviews_review
# 0  Simple yet with great replayability. In my opi...
# 1  I know what you think when you see this title ...
# 2  A suitably punishing roguelike platformer.  Wi...
# 3  This game... is so fun. The fight sequences ha...
# 4                                            Git gud

# %%
# Se implemente una función, que a partir de un texto, extraiga la fecha

def extraer_fecha(texto):
    match = re.search(r'(\w+\s\d{1,2},\s\d{4})', texto)
    if match:
        fecha_str = match.group(1)
        try:
            fecha_dt = pd.to_datetime(fecha_str)
            return fecha_dt.strftime('%Y-%m-%d')
        except:
            return 'Invalido'
    else:
        return 'Invalido'

# %%
# Se extrae la fecha de la columna reviews_posted 
df_reviews['reviews_date'] = df_reviews['reviews_posted'].apply(extraer_fecha)
df_reviews['reviews_date']
# Out:
# 0         2011-11-05
# 1         2014-06-24
# 2           Invalido
# 3         2013-10-14
# 4         2014-04-15
#              ...
# 231919    2014-08-15
# 231921    2014-08-02
# 232047    2015-07-31
# 232127    2015-12-20
# 232129      Invalido
# Name: reviews_date, Length: 59036, dtype: object

# %%
# Se analiza la cantidad de invalidos en la columna reviews_date
df_reviews[df_reviews['reviews_date'] == 'Invalido']
# Out:
#                   user_id                                           user_url  \
# 2               evcentric             http://steamcommunity.com/id/evcentric
# 6       76561198079601835  http://steamcommunity.com/profiles/76561198079...
# 7             MeaTCompany           http://steamcommunity.com/id/MeaTCompany
# 9       76561198156664158  http://steamcommunity.com/profiles/76561198156...
# 10      76561198077246154  http://steamcommunity.com/profiles/76561198077...
# ...                   ...                                                ...
# 224181      steamxanbunny         http://steamcommunity.com/id/steamxanbunny
# 226733          kamineyyy             http://steamcommunity.com/id/kamineyyy
# 228737  76561198071901614  http://steamcommunity.com/profiles/76561198071...
# 229859  76561198082767148  http://steamcommunity.com/profiles/76561198082...
# 232129  76561198209894493  http://steamcommunity.com/profiles/76561198209...
#
#             reviews_posted reviews_item_id  \
# 2       Posted February 3.          248820
# 6           Posted May 20.             730
# 7          Posted July 24.             730
# 9          Posted June 16.          252950
# 10         Posted June 11.             440
# ...                    ...             ...
# 224181    Posted April 12.          394690
# 226733    Posted March 28.          234140
# 228737      Posted May 17.          376210
# 229859   Posted January 3.             730
# 232129  Posted February 3.             570
#
#                                         reviews_helpful  reviews_recommend  \
# 2                                        No ratings yet               True
# 6          0 of 1 people (0%) found this review helpful               True
# 7                                        No ratings yet               True
# 9          0 of 1 people (0%) found this review helpful               True
# 10                                       No ratings yet               True
# ...                                                 ...                ...
# 224181                                   No ratings yet               True
# 226733                                   No ratings yet               True
# 228737  10 of 28 people (36%) found this review helpful               True
# 229859                                   No ratings yet              False
# 232129     0 of 2 people (0%) found this review helpful              False
#
#                                            reviews_review reviews_date
# 2       A suitably punishing roguelike platformer.  Wi...     Invalido
# 6                                           ZIKA DO BAILE     Invalido
# 7                           BEST GAME IN THE BLOODY WORLD     Invalido
# 9                                                 love it     Invalido
# 10                                                 mt bom     Invalido
# ...                                                   ...          ...
# 224181  I cannot say much right now due to the game no...     Invalido
# 226733  Oh what a day .., What a lovely day to play th...     Invalido
# 228737  ░░░░░░░░░░░█▀▀░░█░░░░░░░░░░░▄▀▀▀▀░░░░░█▄▄░░░░░...     Invalido
# 229859                                          got VACed     Invalido
# 232129  DOTA 2.normal skill - 2ez for me>high skill - ...     Invalido
#
# [10100 rows x 8 columns]

# %%
# Se decide elimninar estos datos Invalidos
df_reviews = df_reviews[df_reviews['reviews_date'] != 'Invalido']
df_reviews
# Out:
#                       user_id  \
# 0           76561197970982479
# 1                     js41637
# 3                       doctr
# 4                   maplemage
# 5                      Wackky
# ...                       ...
# 231901      76561198138691719
# 231919     SKELETRONPRIMEISOP
# 231921      76561198141079508
# 232047            ShadowYT100
# 232127  bestcustomurlevermade
#
#                                                  user_url  \
# 0       http://steamcommunity.com/profiles/76561197970...
# 1                    http://steamcommunity.com/id/js41637
# 3                      http://steamcommunity.com/id/doctr
# 4                  http://steamcommunity.com/id/maplemage
# 5                     http://steamcommunity.com/id/Wackky
# ...                                                   ...
# 231901  http://steamcommunity.com/profiles/76561198138...
# 231919    http://steamcommunity.com/id/SKELETRONPRIMEISOP
# 231921  http://steamcommunity.com/profiles/76561198141...
# 232047           http://steamcommunity.com/id/ShadowYT100
# 232127  http://steamcommunity.com/id/bestcustomurlever...
#
#                    reviews_posted reviews_item_id  \
# 0        Posted November 5, 2011.            1250
# 1           Posted June 24, 2014.          251610
# 3        Posted October 14, 2013.          250320
# 4          Posted April 15, 2014.          211420
# 5             Posted May 5, 2014.          249130
# ...                           ...             ...
# 231901  Posted December 30, 2015.          332310
# 231919    Posted August 15, 2014.             440
# 231921     Posted August 2, 2014.          304930
# 232047      Posted July 31, 2015.          265630
# 232127  Posted December 20, 2015.          304050
#
#                                         reviews_helpful  reviews_recommend  \
# 0                                        No ratings yet               True
# 1       15 of 20 people (75%) found this review helpful               True
# 3        2 of 2 people (100%) found this review helpful               True
# 4       35 of 43 people (81%) found this review helpful               True
# 5         7 of 8 people (88%) found this review helpful               True
# ...                                                 ...                ...
# 231901                                   No ratings yet               True
# 231919                                   No ratings yet               True
# 231921                                   No ratings yet               True
# 232047                                   No ratings yet               True
# 232127                                   No ratings yet               True
#
#                                            reviews_review reviews_date
# 0       Simple yet with great replayability. In my opi...   2011-11-05
# 1       I know what you think when you see this title ...   2014-06-24
# 3       This game... is so fun. The fight sequences ha...   2013-10-14
# 4                                                 Git gud   2014-04-15
# 5                                This game is Marvellous.   2014-05-05
# ...                                                   ...          ...
# 231901  Normally I would hardly play a lego based game...   2015-12-30
# 231919  TF2 is alot of fun and its really good but the...   2014-08-15
# 231921                              Fun game with friends   2014-08-02
# 232047                                        So Fun!! :D   2015-07-31
# 232127  This game is great. The only thing is,Why cant...   2015-12-20
#
# [48936 rows x 8 columns]

# %%
# se Renombra la columna reviews_review reviews
df_reviews = df_reviews.rename(columns={'reviews_review': 'reviews'})
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
# 5             Wackky                http://steamcommunity.com/id/Wackky
#
#              reviews_posted reviews_item_id  \
# 0  Posted November 5, 2011.            1250
# 1     Posted June 24, 2014.          251610
# 3  Posted October 14, 2013.          250320
# 4    Posted April 15, 2014.          211420
# 5       Posted May 5, 2014.          249130
#
#                                    reviews_helpful  reviews_recommend  \
# 0                                   No ratings yet               True
# 1  15 of 20 people (75%) found this review helpful               True
# 3   2 of 2 people (100%) found this review helpful               True
# 4  35 of 43 people (81%) found this review helpful               True
# 5    7 of 8 people (88%) found this review helpful               True
#
#                                              reviews reviews_date
# 0  Simple yet with great replayability. In my opi...   2011-11-05
# 1  I know what you think when you see this title ...   2014-06-24
# 3  This game... is so fun. The fight sequences ha...   2013-10-14
# 4                                            Git gud   2014-04-15
# 5                           This game is Marvellous.   2014-05-05

# %%
# Se elimina la columa reviews_posted por considerarse que no es necearia para la Api
df_reviews = df_reviews.drop('reviews_posted', axis=1)
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48936 entries, 0 to 232127
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            48936 non-null  object
#  1   user_url           48936 non-null  object
#  2   reviews_item_id    48936 non-null  object
#  3   reviews_helpful    48936 non-null  object
#  4   reviews_recommend  48936 non-null  bool
#  5   reviews            48909 non-null  object
#  6   reviews_date       48936 non-null  object
# dtypes: bool(1), object(6)
# memory usage: 2.7+ MB

# %%
# En la columna reviews se elimnan los nulos
df_reviews = df_reviews.dropna(subset=['reviews'])
# Se verifican nulos
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48909 entries, 0 to 232127
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            48909 non-null  object
#  1   user_url           48909 non-null  object
#  2   reviews_item_id    48909 non-null  object
#  3   reviews_helpful    48909 non-null  object
#  4   reviews_recommend  48909 non-null  bool
#  5   reviews            48909 non-null  object
#  6   reviews_date       48909 non-null  object
# dtypes: bool(1), object(6)
# memory usage: 2.7+ MB

# %%
# Se verifica la data
df_reviews
# Out:
#                       user_id  \
# 0           76561197970982479
# 1                     js41637
# 3                       doctr
# 4                   maplemage
# 5                      Wackky
# ...                       ...
# 231901      76561198138691719
# 231919     SKELETRONPRIMEISOP
# 231921      76561198141079508
# 232047            ShadowYT100
# 232127  bestcustomurlevermade
#
#                                                  user_url reviews_item_id  \
# 0       http://steamcommunity.com/profiles/76561197970...            1250
# 1                    http://steamcommunity.com/id/js41637          251610
# 3                      http://steamcommunity.com/id/doctr          250320
# 4                  http://steamcommunity.com/id/maplemage          211420
# 5                     http://steamcommunity.com/id/Wackky          249130
# ...                                                   ...             ...
# 231901  http://steamcommunity.com/profiles/76561198138...          332310
# 231919    http://steamcommunity.com/id/SKELETRONPRIMEISOP             440
# 231921  http://steamcommunity.com/profiles/76561198141...          304930
# 232047           http://steamcommunity.com/id/ShadowYT100          265630
# 232127  http://steamcommunity.com/id/bestcustomurlever...          304050
#
#                                         reviews_helpful  reviews_recommend  \
# 0                                        No ratings yet               True
# 1       15 of 20 people (75%) found this review helpful               True
# 3        2 of 2 people (100%) found this review helpful               True
# 4       35 of 43 people (81%) found this review helpful               True
# 5         7 of 8 people (88%) found this review helpful               True
# ...                                                 ...                ...
# 231901                                   No ratings yet               True
# 231919                                   No ratings yet               True
# 231921                                   No ratings yet               True
# 232047                                   No ratings yet               True
# 232127                                   No ratings yet               True
#
#                                                   reviews reviews_date
# 0       Simple yet with great replayability. In my opi...   2011-11-05
# 1       I know what you think when you see this title ...   2014-06-24
# 3       This game... is so fun. The fight sequences ha...   2013-10-14
# 4                                                 Git gud   2014-04-15
# 5                                This game is Marvellous.   2014-05-05
# ...                                                   ...          ...
# 231901  Normally I would hardly play a lego based game...   2015-12-30
# 231919  TF2 is alot of fun and its really good but the...   2014-08-15
# 231921                              Fun game with friends   2014-08-02
# 232047                                        So Fun!! :D   2015-07-31
# 232127  This game is great. The only thing is,Why cant...   2015-12-20
#
# [48909 rows x 7 columns]

# %%
df_reviews.columns
# Out:
# Index(['user_id', 'user_url', 'reviews_item_id', 'reviews_helpful',
#        'reviews_recommend', 'reviews', 'reviews_date'],
#       dtype='object')

# %%
"""  Se adiciona una colunmna o etiqueta sentiment_analysis asignando valores aplicando por medio de la 
 librearia textlob para análisis de sentimientos con NLP, que como se indica en la rubrica, se debe aplicar la siguiente escala:
 debe tomar el valor '0' si es malo, '1' si es neutral y '2' si es positivo. Lo anterior para facilitar el trabajo de los modelos
 de machine learning y el análisis de datos """
    
from textblob import TextBlob


# Definir la función de análisis de sentimientos
def analizar_sentimiento(review):
    if not review:
        return 1  # Neutral if the review is empty or None
    analisis = TextBlob(review)
    if analisis.sentiment.polarity < 0:
        return 0  # Malo
    elif analisis.sentiment.polarity == 0:
        return 1  # Neutral
    else:
        return 2  # Positivo

# Aplicar el análisis de sentimiento directamente
df_reviews['sentiment_analysis'] = df_reviews['reviews'].apply(analizar_sentimiento)

# %%
# Se verifica el estado de la nueva etiqueta
df_reviews
# Out:
#                       user_id  \
# 0           76561197970982479
# 1                     js41637
# 3                       doctr
# 4                   maplemage
# 5                      Wackky
# ...                       ...
# 231901      76561198138691719
# 231919     SKELETRONPRIMEISOP
# 231921      76561198141079508
# 232047            ShadowYT100
# 232127  bestcustomurlevermade
#
#                                                  user_url reviews_item_id  \
# 0       http://steamcommunity.com/profiles/76561197970...            1250
# 1                    http://steamcommunity.com/id/js41637          251610
# 3                      http://steamcommunity.com/id/doctr          250320
# 4                  http://steamcommunity.com/id/maplemage          211420
# 5                     http://steamcommunity.com/id/Wackky          249130
# ...                                                   ...             ...
# 231901  http://steamcommunity.com/profiles/76561198138...          332310
# 231919    http://steamcommunity.com/id/SKELETRONPRIMEISOP             440
# 231921  http://steamcommunity.com/profiles/76561198141...          304930
# 232047           http://steamcommunity.com/id/ShadowYT100          265630
# 232127  http://steamcommunity.com/id/bestcustomurlever...          304050
#
#                                         reviews_helpful  reviews_recommend  \
# 0                                        No ratings yet               True
# 1       15 of 20 people (75%) found this review helpful               True
# 3        2 of 2 people (100%) found this review helpful               True
# 4       35 of 43 people (81%) found this review helpful               True
# 5         7 of 8 people (88%) found this review helpful               True
# ...                                                 ...                ...
# 231901                                   No ratings yet               True
# 231919                                   No ratings yet               True
# 231921                                   No ratings yet               True
# 232047                                   No ratings yet               True
# 232127                                   No ratings yet               True
#
#                                                   reviews reviews_date  \
# 0       Simple yet with great replayability. In my opi...   2011-11-05
# 1       I know what you think when you see this title ...   2014-06-24
# 3       This game... is so fun. The fight sequences ha...   2013-10-14
# 4                                                 Git gud   2014-04-15
# 5                                This game is Marvellous.   2014-05-05
# ...                                                   ...          ...
# 231901  Normally I would hardly play a lego based game...   2015-12-30
# 231919  TF2 is alot of fun and its really good but the...   2014-08-15
# 231921                              Fun game with friends   2014-08-02
# 232047                                        So Fun!! :D   2015-07-31
# 232127  This game is great. The only thing is,Why cant...   2015-12-20
#
#         sentiment_analysis
# 0                        2
# 1                        2
# 3                        2
# 4                        1
# 5                        0
# ...                    ...
# 231901                   0
# 231919                   2
# 231921                   0
# 232047                   2
# 232127                   2
#
# [48909 rows x 8 columns]

# %%
# Finalizando, se exportar el dataset copia a formato parquet
df_reviews.to_parquet('dataset/df_user_reviews_final.parquet', engine='pyarrow')
